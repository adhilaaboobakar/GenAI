# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/healthcare_dataset.csv")

# %%
data.head()
# Out:
#    patient_id  age   bmi  exercise_hours_per_week  smoker  blood_pressure  \
# 0           1   31  18.3                      1.5       0           119.1
# 1           2   44  26.3                      3.1       0           120.5
# 2           3   43  24.2                      4.8       0           130.3
# 3           4   32  25.0                      6.0       0           119.5
# 4           5   28  22.1                      4.2       1           127.4
#
#    diabetes
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
data.shape
# Out:
# (6000, 7)

# %%
data.dtypes
# Out:
# patient_id                   int64
# age                          int64
# bmi                        float64
# exercise_hours_per_week    float64
# smoker                       int64
# blood_pressure             float64
# diabetes                     int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# patient_id                 0
# age                        0
# bmi                        0
# exercise_hours_per_week    0
# smoker                     0
# blood_pressure             0
# diabetes                   0
# dtype: int64

# %%
data.describe()
# Out:
#         patient_id          age          bmi  exercise_hours_per_week  \
# count  6000.000000  6000.000000  6000.000000              6000.000000
# mean   3000.500000    51.107333    25.995267                 3.012800
# std    1732.195139    19.522722     4.960541                 1.491802
# min       1.000000    18.000000    15.000000                 0.000000
# 25%    1500.750000    34.000000    22.500000                 2.000000
# 50%    3000.500000    51.000000    26.100000                 3.000000
# 75%    4500.250000    68.000000    29.400000                 4.000000
# max    6000.000000    84.000000    44.900000                 8.500000
#
#             smoker  blood_pressure     diabetes
# count  6000.000000     6000.000000  6000.000000
# mean      0.307000      134.239733     0.090333
# std       0.461288       11.234260     0.286683
# min       0.000000       94.000000     0.000000
# 25%       0.000000      126.000000     0.000000
# 50%       0.000000      134.200000     0.000000
# 75%       1.000000      142.325000     0.000000
# max       1.000000      169.700000     1.000000

# %%
data['diabetes'].value_counts()
# Out:
# diabetes
# 0    5458
# 1     542
# Name: count, dtype: int64

# %%
data.groupby('diabetes')['age'].mean()
# Out:
# diabetes
# 0    50.376878
# 1    58.463100
# Name: age, dtype: float64

# %%
data.groupby('diabetes')['bmi'].mean()
# Out:
# diabetes
# 0    25.727996
# 1    28.686716
# Name: bmi, dtype: float64

# %%
data.corr()
# Out:
#                          patient_id       age       bmi  \
# patient_id                 1.000000 -0.012029 -0.002037
# age                       -0.012029  1.000000  0.000622
# bmi                       -0.002037  0.000622  1.000000
# exercise_hours_per_week    0.007776 -0.025014  0.015794
# smoker                    -0.000466  0.013981  0.005261
# blood_pressure            -0.019743  0.711919  0.353764
# diabetes                   0.000734  0.118743  0.170992
#
#                          exercise_hours_per_week    smoker  blood_pressure  \
# patient_id                              0.007776 -0.000466       -0.019743
# age                                    -0.025014  0.013981        0.711919
# bmi                                     0.015794  0.005261        0.353764
# exercise_hours_per_week                 1.000000  0.005964       -0.012480
# smoker                                  0.005964  1.000000        0.426725
# blood_pressure                         -0.012480  0.426725        1.000000
# diabetes                               -0.000911 -0.006799        0.149009
#
#                          diabetes
# patient_id               0.000734
# age                      0.118743
# bmi                      0.170992
# exercise_hours_per_week -0.000911
# smoker                  -0.006799
# blood_pressure           0.149009
# diabetes                 1.000000

# %% [markdown]
# Data Visualization

# %%
#1. Distribution of Age Vs Diabetics
plt.figure(figsize=(10,5))
sns.boxplot(x='diabetes', y='age', data=data)
plt.title('Age Vs Diabetics')
plt.xlabel('Diabetics')
plt.ylabel('Age')
plt.show()

# %%
# 2. BMI distribution
sns.histplot(data['bmi'],bins = 20)
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %%
#3. Exercise Vs Diabetics
plt.figure(figsize=(10,5))
sns.boxplot(x='diabetes', y='exercise_hours_per_week', data=data)
plt.title('Exercise Vs Diabetics')
plt.xlabel('Diabetes')
plt.ylabel('Exercise')
plt.show()

# %%
#4.Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True,cmap = 'coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Part 2 - Machine Learning Classification Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
x = data.drop(['diabetes','patient_id'],axis = 1)
y = data['diabetes']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.85)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model = LogisticRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test_scaled)

# %%
#Evaluate Model Performance
accuracy = accuracy_score(y_test,y_pred)
confusion = confusion_matrix(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", confusion)
print("Precision:", precision)
print("Recall:", recall)
print("f1_core:", f1)
# Out:
# Accuracy: 0.9044444444444445
# Confusion Matrix:
#  [[814   0]
#  [ 86   0]]
# Precision: 0.0
# Recall: 0.0
# f1_core: 0.0

# %%
#Confusion matrix visualization
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues',xticklabels=['No Diabetes','Diabetes'],
            yticklabels= ['No Diabetes','Diabetes'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
importance = pd.Series(model.coef_[0], index=x.columns)
importance.sort_values(ascending=False)
# Out:
# bmi                        0.573490
# age                        0.346578
# blood_pressure             0.109498
# exercise_hours_per_week    0.012442
# smoker                    -0.067490
# dtype: float64

# %% [markdown]
# Part 3 - Neural Network Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
nn_model=keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1],),name='input'),
        layers.Dense(32,activation='relu',name='hidden_layer_1'),
        layers.Dense(16,activation='relu',name='hidden_layer_2'),
        layers.Dense(1,activation='sigmoid',name='output_layer')
    ]
)

# %%
nn_model.compile(
    optimizer='adam',
    loss=keras.losses.BinaryCrossentropy(name='binary_cross_entopy'),
    metrics=[
        keras.metrics.BinaryAccuracy(name='Accuracy'),
        keras.metrics.MeanSquaredError(name='MSE')
    ]
)

# %%
nn_model.fit(x_train,y_train,epochs=50,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Accuracy: 0.9106 - MSE: 0.0834 - loss: 0.4735 - val_Accuracy: 0.9044 - val_MSE: 0.0847 - val_loss: 0.3022
# Epoch 2/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0805 - loss: 0.2943 - val_Accuracy: 0.9044 - val_MSE: 0.0853 - val_loss: 0.3052
# Epoch 3/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9104 - MSE: 0.0804 - loss: 0.2944 - val_Accuracy: 0.9044 - val_MSE: 0.0857 - val_loss: 0.3085
# Epoch 4/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9100 - MSE: 0.0808 - loss: 0.2951 - val_Accuracy: 0.9044 - val_MSE: 0.0837 - val_loss: 0.2964
# Epoch 5/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0807 - loss: 0.2965 - val_Accuracy: 0.9044 - val_MSE: 0.0836 - val_loss: 0.2936
# Epoch 6/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9106 - MSE: 0.0806 - loss: 0.2935 - val_Accuracy: 0.9044 - val_MSE: 0.0864 - val_loss: 0.3144
# Epoch 7/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9106 - MSE: 0.0808 - loss: 0.2945 - val_Accuracy: 0.9044 - val_MSE: 0.0828 - val_loss: 0.2918
# Epoch 8/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0801 - loss: 0.2921 - val_Accuracy: 0.9044 - val_MSE: 0.0833 - val_loss: 0.2947
# Epoch 9/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9104 - MSE: 0.0811 - loss: 0.2961 - val_Accuracy: 0.9044 - val_MSE: 0.0830 - val_loss: 0.2910
# Epoch 10/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9102 - MSE: 0.0823 - loss: 0.3021 - val_Accuracy: 0.9044 - val_MSE: 0.0843 - val_loss: 0.2991
# Epoch 11/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9106 - MSE: 0.0800 - loss: 0.2902 - val_Accuracy: 0.9044 - val_MSE: 0.0834 - val_loss: 0.2950
# Epoch 12/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9102 - MSE: 0.0809 - loss: 0.2942 - val_Accuracy: 0.9044 - val_MSE: 0.0858 - val_loss: 0.3091
# Epoch 13/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9104 - MSE: 0.0799 - loss: 0.2900 - val_Accuracy: 0.9044 - val_MSE: 0.0837 - val_loss: 0.2940
# Epoch 14/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9102 - MSE: 0.0801 - loss: 0.2923 - val_Accuracy: 0.9044 - val_MSE: 0.0863 - val_loss: 0.3065
# Epoch 15/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.9104 - MSE: 0.0810 - loss: 0.2962 - val_Accuracy: 0.9044 - val_MSE: 0.0834 - val_loss: 0.2935
# Epoch 34/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Accuracy: 0.9102 - MSE: 0.0801 - loss: 0.2911 - val_Accuracy: 0.9044 - val_MSE: 0.0855 - val_loss: 0.3074
# Epoch 35/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0799 - loss: 0.2925 - val_Accuracy: 0.9044 - val_MSE: 0.0863 - val_loss: 0.3142
# Epoch 36/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9108 - MSE: 0.0798 - loss: 0.2894 - val_Accuracy: 0.9044 - val_MSE: 0.0845 - val_loss: 0.3005
# Epoch 37/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9104 - MSE: 0.0796 - loss: 0.2888 - val_Accuracy: 0.9044 - val_MSE: 0.0832 - val_loss: 0.2932
# Epoch 38/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0795 - loss: 0.2883 - val_Accuracy: 0.9044 - val_MSE: 0.0826 - val_loss: 0.2915
# Epoch 39/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0799 - loss: 0.2898 - val_Accuracy: 0.9044 - val_MSE: 0.0852 - val_loss: 0.2979
# Epoch 40/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0800 - loss: 0.2902 - val_Accuracy: 0.9044 - val_MSE: 0.0840 - val_loss: 0.2964
# Epoch 41/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0790 - loss: 0.2859 - val_Accuracy: 0.9044 - val_MSE: 0.0840 - val_loss: 0.2981
# Epoch 42/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0800 - loss: 0.2900 - val_Accuracy: 0.9044 - val_MSE: 0.0838 - val_loss: 0.2962
# Epoch 43/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0798 - loss: 0.2903 - val_Accuracy: 0.9044 - val_MSE: 0.0850 - val_loss: 0.3056
# Epoch 44/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0800 - loss: 0.2903 - val_Accuracy: 0.9044 - val_MSE: 0.0826 - val_loss: 0.2912
# Epoch 45/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0792 - loss: 0.2871 - val_Accuracy: 0.9044 - val_MSE: 0.0829 - val_loss: 0.2927
# Epoch 46/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0797 - loss: 0.2893 - val_Accuracy: 0.9044 - val_MSE: 0.0828 - val_loss: 0.2916
# Epoch 47/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0800 - loss: 0.2907 - val_Accuracy: 0.9044 - val_MSE: 0.0827 - val_loss: 0.2917
# Epoch 48/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0792 - loss: 0.2861 - val_Accuracy: 0.9044 - val_MSE: 0.0833 - val_loss: 0.2941
# Epoch 49/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0796 - loss: 0.2874 - val_Accuracy: 0.9044 - val_MSE: 0.0840 - val_loss: 0.2978
# Epoch 50/50
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9106 - MSE: 0.0803 - loss: 0.2914 - val_Accuracy: 0.9044 - val_MSE: 0.0860 - val_loss: 0.3118
